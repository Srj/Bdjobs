# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import datetime
import os
import nltk
from tqdm import tqdm
from sklearn.metrics.pairwise import cosine_similarity
from wordcloud import WordCloud
plt.style.use('fivethirtyeight')
sns.set()
plt.rcParams['figure.figsize'] = (12,12)

# %%
import spacy
nlp = spacy.load("en_core_web_lg")

# %%
nltk.download('stopwords')
# Out:
# -------------------------------------------------------------------
# gaierror                          Traceback (most recent call last)
# ~/.conda/envs/Srj/lib/python3.8/urllib/request.py in do_open(self, http_class, req, **http_conn_args)
#    1353             try:
# -> 1354                 h.request(req.get_method(), req.selector, req.data, headers,
#    1355                           encode_chunked=req.has_header('Transfer-encoding'))
#
# ~/.conda/envs/Srj/lib/python3.8/http/client.py in request(self, method, url, body, headers, encode_chunked)
#    1251         """Send a complete request to the server."""
# -> 1252         self._send_request(method, url, body, headers, encode_chunked)
#    1253
#
# ~/.conda/envs/Srj/lib/python3.8/http/client.py in _send_request(self, method, url, body, headers, encode_chunked)
#    1297             body = _encode(body, 'body')
# -> 1298         self.endheaders(body, encode_chunked=encode_chunked)
#    1299
#
# ~/.conda/envs/Srj/lib/python3.8/http/client.py in endheaders(self, message_body, encode_chunked)
#    1246             raise CannotSendHeader()
# -> 1247         self._send_output(message_body, encode_chunked=encode_chunked)
#    1248
#
# ~/.conda/envs/Srj/lib/python3.8/http/client.py in _send_output(self, message_body, encode_chunked)
#    1006         del self._buffer[:]
# -> 1007         self.send(msg)
#    1008
#
# ~/.conda/envs/Srj/lib/python3.8/http/client.py in send(self, data)
#     946             if self.auto_open:
# --> 947                 self.connect()
#     948             else:
#
# ~/.conda/envs/Srj/lib/python3.8/http/client.py in connect(self)
#    1413
# -> 1414             super().connect()
#    1415
#
# ~/.conda/envs/Srj/lib/python3.8/http/client.py in connect(self)
#     917         """Connect to the host and port specified in __init__."""
# --> 918         self.sock = self._create_connection(
#     919             (self.host,self.port), self.timeout, self.source_address)
#
# ~/.conda/envs/Srj/lib/python3.8/socket.py in create_connection(address, timeout, source_address)
#     786     err = None
# --> 787     for res in getaddrinfo(host, port, 0, SOCK_STREAM):
#     788         af, socktype, proto, canonname, sa = res
#
# ~/.conda/envs/Srj/lib/python3.8/socket.py in getaddrinfo(host, port, family, type, proto, flags)
#     917     addrlist = []
# --> 918     for res in _socket.getaddrinfo(host, port, family, type, proto, flags):
#     919         af, socktype, proto, canonname, sa = res
#
# gaierror: [Errno -3] Temporary failure in name resolution
#
# During handling of the above exception, another exception occurred:
#
# KeyboardInterrupt                 Traceback (most recent call last)
# <ipython-input-27-e3fc0c9c9a89> in <module>
# ----> 1 nltk.download('stopwords')
#
# ~/.conda/envs/Srj/lib/python3.8/site-packages/nltk/downloader.py in download(self, info_or_id, download_dir, quiet, force, prefix, halt_on_error, raise_on_error, print_error_to)
#     777                 )
#     778
# --> 779             for msg in self.incr_download(info_or_id, download_dir, force):
#     780                 # Error messages
#     781                 if isinstance(msg, ErrorMessage):
#
# ~/.conda/envs/Srj/lib/python3.8/site-packages/nltk/downloader.py in incr_download(self, info_or_id, download_dir, force)
#     627         # Look up the requested collection or package.
#     628         try:
# --> 629             info = self._info_or_id(info_or_id)
#     630         except (IOError, ValueError) as e:
#     631             yield ErrorMessage(None, "Error loading %s: %s" % (info_or_id, e))
#
# ~/.conda/envs/Srj/lib/python3.8/site-packages/nltk/downloader.py in _info_or_id(self, info_or_id)
#     600     def _info_or_id(self, info_or_id):
#     601         if isinstance(info_or_id, str):
# --> 602             return self.info(info_or_id)
#     603         else:
#     604             return info_or_id
#
# ~/.conda/envs/Srj/lib/python3.8/site-packages/nltk/downloader.py in info(self, id)
#    1009         """Return the ``Package`` or ``Collection`` record for the
#    1010            given item."""
# -> 1011         self._update_index()
#    1012         if id in self._packages:
#    1013             return self._packages[id]
#
# ~/.conda/envs/Srj/lib/python3.8/site-packages/nltk/downloader.py in _update_index(self, url)
#     952         # Download the index file.
#     953         self._index = nltk.internals.ElementWrapper(
# --> 954             ElementTree.parse(urlopen(self._url)).getroot()
#     955         )
#     956         self._index_timestamp = time.time()
#
# ~/.conda/envs/Srj/lib/python3.8/urllib/request.py in urlopen(url, data, timeout, cafile, capath, cadefault, context)
#     220     else:
#     221         opener = _opener
# --> 222     return opener.open(url, data, timeout)
#     223
#     224 def install_opener(opener):
#
# ~/.conda/envs/Srj/lib/python3.8/urllib/request.py in open(self, fullurl, data, timeout)
#     523
#     524         sys.audit('urllib.Request', req.full_url, req.data, req.headers, req.get_method())
# --> 525         response = self._open(req, data)
#     526
#     527         # post-process response
#
# ~/.conda/envs/Srj/lib/python3.8/urllib/request.py in _open(self, req, data)
#     540
#     541         protocol = req.type
# --> 542         result = self._call_chain(self.handle_open, protocol, protocol +
#     543                                   '_open', req)
#     544         if result:
#
# ~/.conda/envs/Srj/lib/python3.8/urllib/request.py in _call_chain(self, chain, kind, meth_name, *args)
#     500         for handler in handlers:
#     501             func = getattr(handler, meth_name)
# --> 502             result = func(*args)
#     503             if result is not None:
#     504                 return result
#
# ~/.conda/envs/Srj/lib/python3.8/urllib/request.py in https_open(self, req)
#    1395
#    1396         def https_open(self, req):
# -> 1397             return self.do_open(http.client.HTTPSConnection, req,
#    1398                 context=self._context, check_hostname=self._check_hostname)
#    1399
#
# ~/.conda/envs/Srj/lib/python3.8/urllib/request.py in do_open(self, http_class, req, **http_conn_args)
#    1352         try:
#    1353             try:
# -> 1354                 h.request(req.get_method(), req.selector, req.data, headers,
#    1355                           encode_chunked=req.has_header('Transfer-encoding'))
#    1356             except OSError as err: # timeout error
#
# KeyboardInterrupt:

# %%
GRAPH = 'Results/Graphs'
TABLE = 'Results/Tables'
DATA = './data'
VERSION = 4  #1: Merged All 2:Cleaned
os.listdir(DATA)
# Out:
# ['Dataset_v3.csv',
#  'Dataset_v2.csv',
#  'Jobs (2016-2018).xlsx',
#  'ONET_Occupations.csv',
#  'Information_Technology.csv',
#  'Dataset_v1.csv',
#  'Jobs (2019-2021) - Bdjobs.xlsx',
#  'skills.csv',
#  'Dataset_v4.csv',
#  'ISCO.csv',
#  'Skill_Rank.csv']

# %% [markdown]
# <h1>Load Pre processed Data</h1>

# %%
df = pd.read_csv(os.path.join(DATA,'Dataset_v'+str(VERSION) + '.csv'))
# ONET = pd.read_csv(os.path.join(DATA,'ONET_Occupations.csv'))
ONET = pd.read_csv(os.path.join(DATA,'Information_Technology.csv'))

# %%
df['JobTitle'] = df['JobTitle'].str.replace('Senior',' ')
df['JobTitle'] = df['JobTitle'].str.replace('Junior',' ')
df['JobTitle'] = df['JobTitle'].str.replace('Sr.',' ')
df['JobTitle'] = df['JobTitle'].str.replace('Jr.',' ')
# Out:
# <ipython-input-95-6c604a66454f>:3: FutureWarning: The default value of regex will change from True to False in a future version.
#   df['JobTitle'] = df['JobTitle'].str.replace('Sr.',' ')
# <ipython-input-95-6c604a66454f>:4: FutureWarning: The default value of regex will change from True to False in a future version.
#   df['JobTitle'] = df['JobTitle'].str.replace('Jr.',' ')

# %%
onet_vector_list = []
for occupation in ONET['Occupation'].values:
    onet_vector_list.append(nlp(occupation.lower()).vector)

# %%
#TESTING
# for title in df.sample(20).JobTitle.values:
    
#     vector_title = nlp(title).vector
#     list_scores = cosine_similarity(onet_vector_list, vector_title.reshape(1,-1))
#     onet_index = list_scores.argmax()
#     print(title + '..................' + ONET.loc[onet_index,'Occupation'])
# Out:
# Digital Marketing Executive (E-commerce Based)..................Web and Digital Interface Designers
# Web Developer..................Web Developers
# Software Engineers (Javascript)..................Software Developers
# IoT and Security Programmer..................Computer Programmers
# Web Developer..................Web Developers
#   IT Officer..................Information Security Analysts
# Technical Project Manager (E-Commerce)..................Information Technology Project Managers
# Business Analyst..................Business Intelligence Analysts
# Front End Developer (React, Vue, AngularJS)..................Computer Occupations, All Other
# WordPress Plugin Developer..................Web Developers
# Program Officer (IT)..................Computer Occupations, All Other
# Software Engineer (PHP Developer)..................Software Developers
#   Executive..................Business Intelligence Analysts
#   Network & System Engineer..................Network and Computer Systems Administrators
# SQA Engineer..................Telecommunications Engineering Specialists
# Android Application Developer..................Software Developers
# PHP/ Web Developer..................Web Developers
# Manager, E-Commerce..................Computer Occupations, All Other
#   Manager/ Manager (Marketing and Sales)..................Information Technology Project Managers
#   ASP .Net/ PHP Programmer..................Computer Programmers

# %%
occupation_list = []
integer_title = df.JobTitle.str.isnumeric()
refined_title = df[~integer_title]
refined_title = refined_title.JobTitle.values
for title in tqdm(refined_title):
#     title = title.lower()
    vector_title = nlp(title).vector
    list_scores = cosine_similarity(onet_vector_list, vector_title.reshape(1,-1))
    onet_index = list_scores.argmax()
    occupation_list.append(ONET.loc[onet_index,'Occupation'])
# Out:
# 100%|██████████| 28316/28316 [02:06<00:00, 223.58it/s]

# %%
len(occupation_list) == len(refined_title)
# Out:
# True

# %%
integer_title = df.JobTitle.str.isnumeric()
df = df[~integer_title]

# %%
df['ONET Title'] = occupation_list

# %%
df.to_csv(os.path.join(DATA,'Dataset_v4.csv'),index=False)

# %% [markdown]
# <h1>Supply Demand</h1>

# %%
df = pd.read_csv(os.path.join(DATA,'Dataset_v4.csv'))

# %%
top_title = df['ONET Title'].value_counts()[:210].index.tolist()
top_title
# Out:
# ['Software Developers',
#  'Web Developers',
#  'Information Technology Project Managers',
#  'Computer Systems Engineers/Architects',
#  'Web and Digital Interface Designers',
#  'Computer User Support Specialists',
#  'Computer Occupations, All Other',
#  'Business Intelligence Analysts',
#  'Project Management Specialists',
#  'Computer Programmers',
#  'Search Marketing Strategists',
#  'Network and Computer Systems Administrators',
#  'Telecommunications Engineering Specialists',
#  'Information Security Analysts',
#  'Computer Network Support Specialists',
#  'Software Quality Assurance Analysts and Testers',
#  'Document Management Specialists',
#  'Database Administrators',
#  'Video Game Designers',
#  'Computer Network Architects',
#  'Computer Systems Analysts',
#  'Data Warehousing Specialists',
#  'Database Architects',
#  'Web Administrators',
#  'Health Informatics Specialists',
#  'Geographic Information Systems Technologists and Technicians']

# %%
top_title_df = df[df['ONET Title'].isin(top_title)]
labor_demand_df = top_title_df.groupby(['ONET Title','Year'])['number_applicants'].sum()/top_title_df.groupby(['ONET Title','Year'])['TotalVacancy'].sum()

labor_demand_df  = pd.DataFrame(labor_demand_df).reset_index(drop=False)
labor_demand_df.rename(columns={0:'Demand'},inplace=True)
labor_demand_df = labor_demand_df.pivot(index='ONET Title',columns='Year',values='Demand')
# labor_demand_df.to_csv(os.path.join(TABLE,'supply_demand.csv'),float_format='%.3f')
labor_demand_df
# Out:
# Year                                                   2016        2017  \
# ONET Title
# Business Intelligence Analysts                   221.187342  135.212025
# Computer Network Architects                      195.000000  371.600000
# Computer Network Support Specialists             258.822967  280.344498
# Computer Occupations, All Other                  295.294807  277.910277
# Computer Programmers                              65.454751   76.293651
# Computer Systems Engineers/Architects            141.301282  117.490925
# Computer User Support Specialists                141.156137  143.185243
# Database Administrators                          132.313433  287.411765
# Document Management Specialists                  211.348148  143.181818
# Information Security Analysts                    217.754098  491.497537
# Information Technology Project Managers          216.300097  222.315539
# Network and Computer Systems Administrators      247.432727  322.491071
# Project Management Specialists                   163.969136  185.558897
# Search Marketing Strategists                     128.366972   82.926606
# Software Developers                               50.582940   52.025929
# Software Quality Assurance Analysts and Testers   96.668712  202.132653
# Telecommunications Engineering Specialists       124.136508   87.230769
# Video Game Designers                              20.647541   16.680851
# Web Developers                                    61.964632   59.568702
# Web and Digital Interface Designers               63.008576   72.789308
#
# Year                                                   2018        2019  \
# ONET Title
# Business Intelligence Analysts                   159.721221  207.945368
# Computer Network Architects                      299.869565  243.610526
# Computer Network Support Specialists             185.395415  310.410000
# Computer Occupations, All Other                  369.706334  385.020325
# Computer Programmers                              53.305376   68.490054
# Computer Systems Engineers/Architects             84.097021   99.749000
# Computer User Support Specialists                138.138411  217.837178
# Database Administrators                          168.703704  304.191489
# Document Management Specialists                  390.207547  237.022472
# Information Security Analysts                    503.714286  591.174312
# Information Technology Project Managers          195.219222  313.959209
# Network and Computer Systems Administrators      230.764085  286.621005
# Project Management Specialists                   160.197943  353.598985
# Search Marketing Strategists                      40.703930  106.050817
# Software Developers                               62.315377   51.800083
# Software Quality Assurance Analysts and Testers  117.346821  220.900000
# Telecommunications Engineering Specialists       104.567619  177.700980
# Video Game Designers                              42.273810   58.494382
# Web Developers                                    68.633760   64.686166
# Web and Digital Interface Designers               57.126866   59.424047
#
# Year                                                   2020        2021
# ONET Title
# Business Intelligence Analysts                   161.166667  175.836538
# Computer Network Architects                      251.678571  237.882353
# Computer Network Support Specialists             274.658120   91.508197
# Computer Occupations, All Other                  330.044665  476.989362
# Computer Programmers                              58.070423   55.894737
# Computer Systems Engineers/Architects             88.234201   34.485199
# Computer User Support Specialists                159.482861   66.299342
# Database Administrators                          151.162162  102.000000
# Document Management Specialists                  302.719298  211.914286
# Information Security Analysts                    504.779817  366.046154
# Information Technology Project Managers          291.506969  192.806159
# Network and Computer Systems Administrators      372.588785  398.000000
# Project Management Specialists                   167.700758  172.070588
# Search Marketing Strategists                     140.066038   88.450893
# Software Developers                               50.445705   37.935988
# Software Quality Assurance Analysts and Testers  115.448276  114.916667
# Telecommunications Engineering Specialists       129.496774  124.341317
# Video Game Designers                              21.652174   60.812500
# Web Developers                                    50.470909   37.787879
# Web and Digital Interface Designers               86.755294   60.294444

# %% [markdown]
# <h1>High Demand Job</h1>

# %%
years = list(range(2016,2022))
rank_df = pd.DataFrame(columns =[*years])
for YEAR in years:
    year_df = df[df['Year'] == YEAR]
    top_title = year_df['ONET Title'].value_counts()[:100].index.tolist()
    for rank,title in enumerate(top_title):
        rank_df.loc[title,YEAR] = rank+1
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~/.conda/envs/Srj/lib/python3.8/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    3080             try:
# -> 3081                 return self._engine.get_loc(casted_key)
#    3082             except KeyError as err:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'ONET Title'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-8-14befa1101f8> in <module>
#       3 for YEAR in years:
#       4     year_df = df[df['Year'] == YEAR]
# ----> 5     top_title = year_df['ONET Title'].value_counts()[:100].index.tolist()
#       6     for rank,title in enumerate(top_title):
#       7         rank_df.loc[title,YEAR] = rank+1
#
# ~/.conda/envs/Srj/lib/python3.8/site-packages/pandas/core/frame.py in __getitem__(self, key)
#    3022             if self.columns.nlevels > 1:
#    3023                 return self._getitem_multilevel(key)
# -> 3024             indexer = self.columns.get_loc(key)
#    3025             if is_integer(indexer):
#    3026                 indexer = [indexer]
#
# ~/.conda/envs/Srj/lib/python3.8/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    3081                 return self._engine.get_loc(casted_key)
#    3082             except KeyError as err:
# -> 3083                 raise KeyError(key) from err
#    3084
#    3085         if tolerance is not None:
#
# KeyError: 'ONET Title'

# %%
rank_df.head(10)
# Out:
#                                         2016 2017 2018 2019 2020 2021
# Software Developers                        1    1    1    1    1    1
# Web Developers                             2    2    2    2    2    2
# Information Technology Project Managers    3    3    3    3    3    3
# Computer Systems Engineers/Architects      4    6    6    5    4    4
# Computer User Support Specialists          5    5    7    7    5    6
# Computer Occupations, All Other            6    7    5    6    6    7
# Business Intelligence Analysts             7    8    8    8    8    8
# Web and Digital Interface Designers        8    4    4    4    7    5
# Project Management Specialists             9    9    9   11   10    9
# Computer Programmers                      10   10   11    9   11   11

# %%
rank_df.head(10).to_csv(os.path.join(TABLE,'title_rank.csv'),float_format='%.3f')

# %%
freq = {key: value for key,value in df['ONET Title'].value_counts().items()}

# %%
len(freq)
# Out:
# 26

# %%
plt.rcParams['figure.figsize']= (12,12)
wc = WordCloud(background_color="white",width=1000,height=1000, max_words=50,relative_scaling=0.1,normalize_plurals=False).generate_from_frequencies(freq)
plt.imshow(wc)
plt.savefig('WordCloud.png',dpi=350)

# %%
from collections import Counter
from nltk.tokenize import TreebankWordTokenizer

# %%
full_context = ' '.join(df['Job_Responsibility'].astype(str).values)
tokens = TreebankWordTokenizer().tokenize(full_context)

# %%
len(tokens)
# Out:
# 2984591

# %%
from nltk.corpus import stopwords
stop_words = set(stopwords.words('english'))
tokens = [t for t in tokens if t not in stop_words]

# %%
counter = Counter(tokens)

# %%
counter.most_common(1000)
# Out:
# [(',', 195553),
#  ('&', 28207),
#  (')', 17871),
#  ('(', 17687),
#  (';', 15708),
#  ('software', 14002),
#  ('development', 13672),
#  ('knowledge', 12659),
#  ('design', 12005),
#  ('team', 10861),
#  ('new', 10002),
#  ('experience', 9205),
#  ('support', 8828),
#  ('#', 8759),
#  ('work', 8536),
#  ('IT', 8404),
#  ('technical', 8048),
#  ('system', 7962),
#  ('data', 7829),
#  ('web', 7635),
#  ('business', 7499),
#  ('Must', 7206),
#  ('project', 7156),
#  ('Design', 6900),
#  ('Experience', 6848),
#  ('etc.', 6794),
#  ('using', 6720),
#  ('Develop', 6700),
#  ('network', 6680),
#  ('systems', 6601),
#  ('application', 6470),
#  ('management', 6390),
#  ('maintain', 6329),
#  ('applications', 6167),
#  ('requirements', 6162),
#  ('code', 5997),
#  (':', 5713),
#  ('ensure', 5702),
#  ('performance', 5372),
#  ('develop', 5144),
#  ('Ensure', 5143),
#  ('test', 5121),
#  ('Work', 5076),
#  ('including', 4949),
#  ('related', 4833),
#  ('understanding', 4734),
#  ('based', 4687),
#  ('user', 4684),
#  ('product', 4673),
#  ('Maintain', 4499),
#  ('To', 4470),
#  ('testing', 4434),
#  ('quality', 4428),
#  ('PHP', 4310),
#  ('solutions', 4294),
#  ('Provide', 4283),
#  ('database', 4282),
#  ('working', 4252),
#  ('customer', 4205),
#  ('Web', 4204),
#  ('Knowledge', 4126),
#  ('marketing', 4116),
#  ('security', 4081),
#  ('.', 3998),
#  ('hardware', 3979),
#  ('existing', 3908),
#  ('technologies', 3849),
#  ('Strong', 3845),
#  ('issues', 3739),
#  ('tools', 3709),
#  ('different', 3703),
#  ('maintenance', 3635),
#  ('implement', 3612),
#  ('Server', 3604),
#  ('Good', 3579),
#  ('SQL', 3559),
#  ('like', 3487),
#  ('projects', 3486),
#  ('good', 3483),
#  ('skills', 3432),
#  ('documentation', 3341),
#  ('Manage', 3341),
#  ('information', 3305),
#  ('service', 3258),
#  ('services', 3250),
#  ('Software', 3244),
#  ('process', 3204),
#  ('client', 3190),
#  ('Ability', 3130),
#  ('content', 3085),
#  ('server', 3085),
#  ('various', 3077),
#  ('problems', 3032),
#  ('/', 2966),
#  ('Should', 2932),
#  ('JavaScript', 2911),
#  ('per', 2911),
#  ('implementation', 2895),
#  ('best', 2884),
#  ('analysis', 2858),
#  ('Prepare', 2844),
#  ('provide', 2837),
#  ('sales', 2836),
#  ('computer', 2804),
#  ('Network', 2756),
#  ('developing', 2749),
#  ('Perform', 2725),
#  ('mobile', 2719),
#  ('required', 2716),
#  ('The', 2692),
#  ('communication', 2674),
#  ('training', 2667),
#  ('assigned', 2649),
#  ('company', 2636),
#  ('Support', 2635),
#  ('Create', 2633),
#  ('SEO', 2568),
#  ('complex', 2561),
#  ('report', 2559),
#  ('Android', 2545),
#  ('technology', 2538),
#  ('activities', 2530),
#  ('API', 2509),
#  ('manage', 2509),
#  ('users', 2504),
#  ('Development', 2499),
#  ('reports', 2477),
#  ('Management', 2453),
#  ('end', 2442),
#  ('within', 2430),
#  ('time', 2417),
#  ('teams', 2414),
#  ('products', 2354),
#  ('clients', 2334),
#  ('practices', 2329),
#  ('troubleshooting', 2317),
#  ('website', 2311),
#  ('monitoring', 2285),
#  ('well', 2268),
#  ('internal', 2256),
#  ('Responsible', 2244),
#  ('media', 2243),
#  ('strong', 2223),
#  ('-', 2223),
#  ('ERP', 2199),
#  ('programming', 2195),
#  ('members', 2190),
#  ('high', 2182),
#  ('build', 2150),
#  ('CSS', 2141),
#  ('able', 2129),
#  ('social', 2124),
#  ('configuration', 2118),
#  ('Working', 2105),
#  ('standards', 2104),
#  ('must', 2065),
#  ('processes', 2048),
#  ('needs', 2048),
#  ('level', 2046),
#  ('System', 2025),
#  ('Oracle', 2020),
#  ('coding', 2018),
#  ('Excellent', 2006),
#  ('Analyze', 1983),
#  ('necessary', 1977),
#  ('You', 1970),
#  ('HTML', 1963),
#  ('requirement', 1952),
#  ('Identify', 1950),
#  ('standard', 1947),
#  ('plan', 1920),
#  ('maintaining', 1910),
#  ('Data', 1909),
#  ('writing', 1901),
#  ('digital', 1896),
#  ('control', 1890),
#  ('meet', 1883),
#  ('multiple', 1874),
#  ('customers', 1864),
#  ('Database', 1842),
#  ('requirements.', 1830),
#  ('applications.', 1824),
#  ('Monitor', 1822),
#  ('Write', 1819),
#  ('integration', 1810),
#  ('problem', 1802),
#  ('use', 1801),
#  ('create', 1800),
#  ('MySQL', 1800),
#  ('Assist', 1798),
#  ('planning', 1791),
#  ('equipment', 1790),
#  ('APIs', 1764),
#  ('Collaborate', 1760),
#  ('Google', 1759),
#  ('MVC', 1757),
#  ('specifications', 1744),
#  ('tasks', 1735),
#  ('features', 1721),
#  ('C', 1716),
#  ('understand', 1708),
#  ('procedures', 1698),
#  ('environment', 1694),
#  ('Java', 1683),
#  ('improve', 1683),
#  ('WordPress', 1676),
#  ('HTML5', 1667),
#  ('responsible', 1665),
#  ('installation', 1660),
#  ('Have', 1655),
#  ('relevant', 1653),
#  ('UI', 1652),
#  ('nan', 1640),
#  ('functional', 1639),
#  ('according', 1637),
#  ('identify', 1620),
#  ('appropriate', 1608),
#  ('plans', 1607),
#  ('architecture', 1607),
#  ('regular', 1584),
#  ('solution', 1579),
#  ('designing', 1579),
#  ('infrastructure', 1576),
#  ('online', 1576),
#  ('IP', 1555),
#  ('reporting', 1548),
#  ('developers', 1547),
#  ('team.', 1542),
#  ('proper', 1539),
#  ('Developing', 1538),
#  ('framework', 1534),
#  ('LAN', 1528),
#  ('current', 1523),
#  ('ideas', 1517),
#  ('Windows', 1501),
#  ('Application', 1501),
#  ('platform', 1479),
#  ('Laravel', 1479),
#  ('trends', 1473),
#  ('Microsoft', 1473),
#  ('site', 1462),
#  ('Linux', 1460),
#  ('following', 1457),
#  ('Understanding', 1451),
#  ('ability', 1443),
#  ('across', 1428),
#  ('required.', 1425),
#  ('Maintenance', 1420),
#  ('closely', 1397),
#  ('jQuery', 1396),
#  ('Any', 1387),
#  ('configure', 1375),
#  ('efficient', 1372),
#  ('stakeholders', 1370),
#  ('systems.', 1366),
#  ('Configure', 1362),
#  ('Plan', 1359),
#  ('management.', 1357),
#  ('frameworks', 1354),
#  ('Implement', 1353),
#  ('CSS3', 1343),
#  ('development.', 1340),
#  ('Monitoring', 1340),
#  ('daily', 1335),
#  ('We', 1331),
#  ('execute', 1326),
#  ('operation', 1325),
#  ('changes', 1324),
#  ('operating', 1323),
#  ('effective', 1319),
#  ('resolve', 1312),
#  ('backup', 1308),
#  ('research', 1308),
#  ('MS', 1304),
#  ('solving', 1303),
#  ('strategies', 1297),
#  ('update', 1293),
#  ('iOS', 1282),
#  ('software.', 1280),
#  ('market', 1276),
#  ('Bootstrap', 1276),
#  ('production', 1274),
#  ('Project', 1272),
#  ('organization', 1266),
#  ('Participate', 1265),
#  ('also', 1262),
#  ('delivery', 1261),
#  ('documents', 1254),
#  ('English', 1254),
#  ('Test', 1252),
#  ('building', 1250),
#  ('staff', 1245),
#  ('servers', 1242),
#  ('managing', 1232),
#  ('strategy', 1230),
#  ('Facebook', 1229),
#  ('Installation', 1228),
#  ('etc', 1227),
#  ('troubleshoot', 1225),
#  ('operational', 1223),
#  ('monitor', 1221),
#  ('Marketing', 1219),
#  ('email', 1219),
#  ('communicate', 1207),
#  ('task', 1201),
#  ('timely', 1201),
#  ('Conduct', 1199),
#  ('day', 1193),
#  ('make', 1192),
#  ('professional', 1189),
#  ('external', 1189),
#  ('order', 1185),
#  ('Hardware', 1182),
#  ('operations', 1181),
#  ('deliver', 1180),
#  ('Install', 1175),
#  ('platforms', 1173),
#  ('latest', 1166),
#  ('Build', 1166),
#  ('office', 1162),
#  ('lead', 1162),
#  ('Report', 1160),
#  ('websites', 1159),
#  ('cases', 1157),
#  ('skill', 1156),
#  ('Business', 1154),
#  ('JSON', 1145),
#  ('prepare', 1140),
#  ('Team', 1140),
#  ('analyze', 1137),
#  ('access', 1136),
#  ('system.', 1134),
#  ('key', 1129),
#  ('issues.', 1127),
#  ('Research', 1126),
#  ('concepts', 1124),
#  ('Framework', 1121),
#  ('designs', 1118),
#  ('Coordinate', 1115),
#  ('Designing', 1115),
#  ('queries', 1113),
#  ('overall', 1107),
#  ('looking', 1107),
#  ('Writing', 1106),
#  ('CCTV', 1106),
#  ('ensuring', 1103),
#  ('document', 1102),
#  ('help', 1101),
#  ('networking', 1097),
#  ('front-end', 1090),
#  ('databases', 1082),
#  ('take', 1080),
#  ('review', 1076),
#  ('years', 1076),
#  ('Able', 1075),
#  ('Managing', 1072),
#  ('creative', 1069),
#  ('skills.', 1069),
#  ('AJAX', 1051),
#  ('Photoshop', 1051),
#  ('Adobe', 1049),
#  ('devices', 1048),
#  ('evaluate', 1048),
#  ('projects.', 1047),
#  ('Internet', 1045),
#  ('implementing', 1044),
#  ('Troubleshoot', 1038),
#  ('industry', 1036),
#  ('life', 1033),
#  ('optimization', 1033),
#  ('job', 1031),
#  ('networks', 1025),
#  ('and/or', 1024),
#  ('Technical', 1023),
#  ('OOP', 1022),
#  ('need', 1022),
#  ('Lead', 1018),
#  ('bugs', 1012),
#  ('achieve', 1002),
#  ('Solid', 998),
#  ('components', 994),
#  ('highly', 994),
#  ('apps', 992),
#  ('complete', 987),
#  ('policies', 986),
#  ('campaigns', 986),
#  ('Troubleshooting', 985),
#  ('e.g.', 975),
#  ('opportunities', 962),
#  ('reusable', 961),
#  ('company`s', 959),
#  ('deployment', 959),
#  ('Follow', 958),
#  ('Providing', 958),
#  ('REST', 957),
#  ('follow', 956),
#  ('techniques', 955),
#  ('clean', 954),
#  ('services.', 954),
#  ('Core', 950),
#  ('Security', 947),
#  ('smooth', 945),
#  ('Familiarity', 944),
#  ('Maintaining', 940),
#  ('back-end', 939),
#  ('core', 936),
#  ('part', 933),
#  ('improvement', 932),
#  ('responsibilities', 925),
#  ('progress', 922),
#  ('potential', 918),
#  ('objectives', 918),
#  ('resources', 918),
#  ('bug', 918),
#  ('developer', 917),
#  ('full', 916),
#  ('Social', 915),
#  ('ICT', 910),
#  ('write', 907),
#  ('search', 896),
#  ('tests', 894),
#  ('Sound', 893),
#  ('ASP.NET', 889),
#  ('source', 885),
#  ('concept', 878),
#  ('automation', 878),
#  ('unit', 876),
#  ('solutions.', 871),
#  ('Analysis', 868),
#  ('JQuery', 867),
#  ('clear', 866),
#  ('results', 866),
#  ('written', 865),
#  ('feedback', 865),
#  ('deadlines', 863),
#  ('Review', 863),
#  ('Programming', 862),
#  ('vendors', 862),
#  ('Service', 859),
#  ('effectively', 859),
#  ('Angular', 857),
#  ('Communicate', 855),
#  ('responsive', 851),
#  ('Services', 850),
#  ('configuring', 850),
#  ('target', 849),
#  ('needed', 849),
#  ('areas', 849),
#  ('goals', 847),
#  ('XML', 844),
#  ('app', 842),
#  ('analyzing', 840),
#  ('plus', 839),
#  ('problems.', 838),
#  ('learn', 831),
#  ('Router', 831),
#  ('cycle', 830),
#  ('Planning', 828),
#  ('Creating', 827),
#  ('include', 827),
#  ('providing', 824),
#  ('set', 822),
#  ('solve', 822),
#  ('recovery', 820),
#  ('Access', 818),
#  ('Ensuring', 817),
#  ('perform', 815),
#  ('detailed', 814),
#  ('User', 814),
#  ('functionality', 813),
#  ('analytical', 813),
#  ('developed', 812),
#  ('duties', 811),
#  ('programs', 811),
#  ('WAN', 810),
#  ('technologies.', 809),
#  ('administration', 808),
#  ('Object', 803),
#  ('brand', 802),
#  ('define', 802),
#  ('creating', 801),
#  ('time.', 800),
#  ('PC', 799),
#  ('.NET', 796),
#  ('engineering', 795),
#  ('Be', 792),
#  ('scope', 790),
#  ('accounts', 786),
#  ('future', 780),
#  ('Mobile', 779),
#  ('Expert', 778),
#  ('monthly', 777),
#  ('connectivity', 775),
#  ('status', 774),
#  ('interface', 774),
#  ('Candidate', 771),
#  ('code.', 769),
#  ('environment.', 768),
#  ('coordinate', 767),
#  ('Basic', 762),
#  ('availability', 761),
#  ('program', 760),
#  ('one', 760),
#  ('Git', 756),
#  ('link', 753),
#  ('version', 753),
#  ('Media', 752),
#  ('expertise', 750),
#  ('Product', 748),
#  ('meetings', 746),
#  ('Testing', 745),
#  ('inventory', 743),
#  ('role', 741),
#  ('candidate', 740),
#  ('Office', 740),
#  ('graphics', 739),
#  ('innovative', 738),
#  ('A', 736),
#  ('local', 734),
#  ('materials', 734),
#  ('strategic', 733),
#  ('Control', 731),
#  ('printers', 729),
#  ('Oriented', 729),
#  ('regarding', 728),
#  ('2494', 728),
#  ('Sales', 727),
#  ('Manager', 726),
#  ('automated', 726),
#  ('capability', 724),
#  ('support.', 722),
#  ('Understand', 720),
#  ('compliance', 719),
#  ('Keep', 718),
#  ('Implementation', 715),
#  ('large', 711),
#  ('scalable', 711),
#  ('making', 709),
#  ('apply', 708),
#  ('Ajax', 707),
#  ('Javascript', 705),
#  ('schedule', 704),
#  ('Integration', 701),
#  ('debugging', 700),
#  ('QA', 699),
#  ('custom', 698),
#  ('basis', 697),
#  ('Illustrator', 695),
#  ('libraries', 694),
#  ('patterns', 693),
#  ('budget', 692),
#  ('sites', 690),
#  ('line', 689),
#  ('reviews', 689),
#  ('continuous', 689),
#  ('least', 688),
#  ('release', 688),
#  ('JS', 685),
#  ('plus.', 683),
#  ('accurate', 683),
#  ('relationship', 682),
#  ('field', 682),
#  ('enterprise', 682),
#  ('React', 681),
#  ('relationships', 679),
#  ('position', 678),
#  ('Computer', 677),
#  ('optimize', 677),
#  ('guidelines', 677),
#  ('users.', 676),
#  ('Agile', 675),
#  ('execution', 675),
#  ('Proficient', 675),
#  ('Need', 673),
#  ('clients.', 672),
#  ('organizational', 672),
#  ('storage', 671),
#  ('advanced', 670),
#  ('Document', 670),
#  ('party', 665),
#  ('This', 663),
#  ('Other', 662),
#  ('basic', 658),
#  ('specific', 658),
#  ('2', 656),
#  ('Installing', 654),
#  ('principles', 654),
#  ('department', 650),
#  ('2480', 650),
#  ('track', 649),
#  ('managers', 648),
#  ('resolution', 646),
#  ('fix', 645),
#  ('enhance', 643),
#  ('oriented', 642),
#  ('leadership', 640),
#  ('activities.', 638),
#  ('aspects', 638),
#  ('assist', 638),
#  ('performance.', 636),
#  ('client`s', 636),
#  ('independently', 635),
#  ('Help', 632),
#  ('drive', 631),
#  ('cloud', 631),
#  ('creation', 630),
#  ('traffic', 630),
#  ('scripts', 629),
#  ('throughout', 629),
#  ('usability', 627),
#  ('Clear', 624),
#  ('Systems', 622),
#  ('vendor', 622),
#  ('functions', 620),
#  ('internet', 619),
#  ('learning', 618),
#  ('2509', 618),
#  ('standards.', 617),
#  ('general', 617),
#  ('guidance', 616),
#  ('query', 616),
#  ('setup', 616),
#  ('Printer', 614),
#  ('excellent', 614),
#  ('efficiency', 613),
#  ('Contribute', 611),
#  ('others', 611),
#  ('works', 611),
#  ('corporate', 610),
#  ('updates', 610),
#  ('MIS', 608),
#  ('handle', 608),
#  ('video', 608),
#  ('languages', 607),
#  ('phone', 606),
#  ('successful', 604),
#  ('international', 602),
#  ('recommendations', 602),
#  ('ongoing', 601),
#  ('Establish', 599),
#  ('trouble', 599),
#  ('VPN', 599),
#  ('practices.', 599),
#  ('types', 598),
#  ('get', 598),
#  ('engineers', 597),
#  ('running', 596),
#  ('experienced', 596),
#  ('layouts', 595),
#  ('keep', 595),
#  ('responsibility', 593),
#  ('Customer', 591),
#  ('tools.', 591),
#  ('RESTful', 591),
#  ('modern', 589),
#  ('Preparing', 588),
#  ('may', 588),
#  ('mail', 587),
#  ('issue', 586),
#  ('flow', 586),
#  ('Cisco', 585),
#  ('determine', 584),
#  ('Content', 583),
#  ('Excel', 582),
#  ('charts', 580),
#  ('testable', 580),
#  ('requests', 580),
#  ('departments', 579),
#  ('deploy', 579),
#  ('needs.', 579),
#  ('given', 577),
#  ('Experienced', 577),
#  ('change', 575),
#  ('page', 573),
#  ('maintenance.', 571),
#  ('Digital', 569),
#  ('Take', 568),
#  ('sound', 568),
#  ('third', 567),
#  ('improvements', 565),
#  ('dynamic', 564),
#  ('architectural', 564),
#  ('Reporting', 558),
#  ('date', 555),
#  ('modules', 555),
#  ('cross-functional', 555),
#  ('entire', 554),
#  ('Twitter', 554),
#  ('•', 553),
#  ('DNS', 551),
#  ('Information', 551),
#  ('Job', 551),
#  ('Crystal', 550),
#  ('Configuration', 550),
#  ('open', 550),
#  ('Capable', 548),
#  ('conduct', 546),
#  ('remote', 546),
#  ('individual', 546),
#  ('capacity', 545),
#  ('partners', 545),
#  ('increase', 545),
#  ('expert', 542),
#  ('possible', 542),
#  ('layout', 541),
#  ('Online', 541),
#  ('know', 540),
#  ('desktop', 540),
#  ('Update', 540),
#  ('presentation', 539),
#  ('variety', 537),
#  ('CMS', 537),
#  ('deliverables', 537),
#  ('Website', 536),
#  ('handling', 535),
#  ('Python', 531),
#  ('along', 531),
#  ('upgrades', 529),
#  ('improving', 529),
#  ('sources', 528),
#  ('base', 527),
#  ('translate', 526),
#  ('design.', 525),
#  ('interfaces', 523),
#  ('Developer', 523),
#  ('requirement.', 522),
#  ('Switch', 521),
#  ('Active', 520),
#  ('Camera', 520),
#  ('critical', 519),
#  ('post', 518),
#  ('case', 518),
#  ('visual', 517),
#  ('Magento', 517),
#  ('via', 517),
#  ('router', 515),
#  ('usage', 515),
#  ('3', 515),
#  ('Desktop', 511),
#  ('Optimize', 511),
#  ('delivering', 509),
#  ('Use', 509),
#  ('Evaluate', 509),
#  ('produce', 509),
#  ('ASP.Net', 507),
#  ('fixing', 507),
#  ('documentation.', 507),
#  ('application.', 507),
#  ('Proven', 507),
#  ('basis.', 506),
#  ('maximize', 506),
#  ('project.', 505),
#  ('Email', 504),
#  ('device', 503),
#  ('Will', 503),
#  ('Spring', 503),
#  ('Communication', 502),
#  ('growth', 502),
#  ('AWS', 501),
#  ('Training', 500),
#  ('ownership', 500),
#  ('point', 499),
#  ('risk', 499),
#  ('value', 498),
#  ('Networking', 497),
#  ('Laptop', 496),
#  ('preparing', 495),
#  ('Execute', 495),
#  ('Deep', 494),
#  ('area', 493),
#  ('diagrams', 493),
#  ('environments', 492),
#  ('Building', 492),
#  ('theme', 492),
#  ('experience.', 492),
#  ('lifecycle', 491),
#  ('elements', 491),
#  ('tuning', 490),
#  ('customers.', 489),
#  ('Mail', 489),
#  ('organization.', 489),
#  ('UX', 489),
#  ('Administration', 489),
#  ('pressure', 488),
#  ('implementation.', 488),
#  ('platform.', 488),
#  ('Make', 488),
#  ('provided', 487),
#  ('leading', 487),
#  ('Advanced', 484),
#  ('campaign', 484),
#  ('Wordpress', 483),
#  ('graphic', 482),
#  ('needed.', 482),
#  ('specification', 482),
#  ('Requirement', 481),
#  ('comprehensive', 480),
#  ('file', 480),
#  ('upgrade', 480),
#  ('AngularJS', 479),
#  ('used', 479),
#  ('Implementing', 479),
#  ('Technology', 478),
#  ('policy', 478),
#  ('SAP', 478),
#  ('install', 477),
#  ('weekly', 476),
#  ('company.', 476),
#  ('pages', 476),
#  ('codes', 475),
#  ('procedures.', 474),
#  ('In', 474),
#  ('financial', 474),
#  ('Familiar', 473),
#  ('Head', 472),
#  ('integrate', 472),
#  ('added', 471),
#  ('initiatives', 469),
#  ('Performing', 468),
#  ('check', 467),
#  ('printer', 467),
#  ('Having', 467),
#  ('keyword', 467),
#  ('.Net', 467),
#  ('Setup', 465),
#  ('recommend', 464),
#  ('Continuously', 464),
#  ('visit', 461),
#  ('senior', 461),
#  ('add', 460),
#  ('integrity', 460),
#  ('meeting', 459),
#  ('framework.', 459),
#  ('member', 459),
#  ('cost', 459),
#  ('scale', 458),
#  ('computers', 458),
#  ('includes', 458),
#  ('record', 457),
#  ('front', 457),
#  ('outside', 456),
#  ('contribute', 456),
#  ('type', 453),
#  ('5', 453),
#  ('Code', 453),
#  ('Quality', 452),
#  ('Extensive', 452),
#  ('collection', 451),
#  ('assets', 451),
#  ('processes.', 451),
#  ('studying', 450),
#  ('UI/UX', 450),
#  ('identifying', 449),
#  ('manager', 447),
#  ('members.', 446),
#  ('solid', 446),
#  ('designers', 445),
#  ('Search', 445),
#  ('supports', 444),
#  ('equipment.', 444),
#  ('language', 443),
#  ('protection', 443),
#  ('SMS', 442),
#  ('PSD', 441),
#  ('assistance', 441),
#  ('relational', 441),
#  ('assurance', 439),
#  ('necessary.', 439),
#  ('manual', 439),
#  ('Firewall', 438),
#  ('contents', 438),
#  ('Operation', 437),
#  ('analytics', 437),
#  ('properly', 437),
#  ('?', 437),
#  ('2503', 437),
#  ('Enterprise', 436),
#  ('App', 436),
#  ('sure', 436),
#  ('personnel', 434),
#  ('editing', 434),
#  ('risks', 431),
#  ('channels', 430),
#  ('prioritize', 430),
#  ('efforts', 430),
#  ('process.', 430),
#  ('accordance', 430),
#  ('right', 429),
#  ('methodologies', 427),
#  ('final', 426),
#  ('supporting', 426),
#  ('must.', 424),
#  ('maximum', 423),
#  ('features.', 422),
#  ('Directory', 421),
#  ('establishing', 421),
#  ('Company', 421),
#  ('reports.', 420),
#  ('Track', 420),
#  ('agile', 420),
#  ('Applications', 419),
#  ('supervision', 419),
#  ('i.e.', 418),
#  ('testing.', 418),
#  ('shooting', 418),
#  ('activity', 417),
#  ('As', 417),
#  ('Documentation', 417),
#  ('responsiveness', 416),
#  ('Graphics', 415),
#  ('generate', 414),
#  ('live', 413),
#  ('2453', 412),
#  ('LinkedIn', 411),
#  ('advertising', 410),
#  ('disaster', 410),
#  ('network.', 410),
#  ('resource', 410),
#  ('engine', 409),
#  ('YouTube', 409),
#  ('Integrate', 408),
#  ('direction', 408),
#  ('processing', 408),
#  ('feature', 408),
#  ('high-quality', 407),
#  ('designed', 406),
#  ('evaluating', 406),
#  ('Client', 406),
#  ('player', 406),
#  ('products.', 406),
#  ('established', 406),
#  ('Management.', 405),
#  ('web-based', 405),
#  ('audit', 405),
#  ('regularly', 404),
#  ('Very', 404),
#  ('preparation', 404),
#  ('quickly', 404),
#  ('parts', 404),
#  ('Responsibilities', 404),
#  ('verbal', 403),
#  ('presentations', 403),
#  ('every', 402),
#  ('work.', 402),
#  ('Daily', 401),
#  ('present', 401),
#  ('Bangladesh', 400),
#  ('OS', 400),
#  ('third-party', 399),
#  ('manner', 399),
#  ('Operating', 398),
#  ('compatibility', 397),
#  ('Handle', 397),
#  ('schedules', 397),
#  ('debug', 396),
#  ('wireframes', 396),
#  ('2472', 396),
#  ('keeping', 395),
#  ('call', 395),
#  ('establish', 394),
#  ('records', 394),
#  ('power', 393),
#  ('side', 393),
#  ('share', 393),
#  ('phases', 392),
#  ("''", 392),
#  ('domain', 392),
#  ('SDK', 392),
#  ('All', 391),
#  ('1', 391),
#  ('Analytics', 390),
#  ('background', 389),
#  ('limited', 389),
#  ('correct', 388),
#  ('Produce', 388),
#  ('Cloud', 387),
#  ('capable', 387),
#  ('Supervise', 386),
#  ('Power', 386),
#  ('faults', 385),
#  ('tracking', 385),
#  ('major', 385),
#  ('devices.', 384),
#  ('emerging', 383),
#  ('SDLC', 382),
#  ('structure', 382),
#  ('focus', 380),
#  ('platforms.', 380),
#  ('Mikrotik', 380),
#  ('payment', 378),
#  ('feasibility', 378),
#  ('Define', 377),
#  ('efficiently', 377),
#  ('experiences', 377),
#  ('Concept', 377),
#  ('Engineer', 376),
#  ('native', 375),
#  ('Entity', 374),
#  ('e-commerce', 374),
#  ('installing', 372)]

# %%
import collections
import re
import sys
import time


def tokenize(string):
    """Convert string to lowercase and split into words (ignoring
    punctuation), returning list of words.
    """
    return re.findall(r'\w+', string.lower())


def count_ngrams(lines, min_length=2, max_length=2):
    """Iterate through given lines iterator (file object or list of
    lines) and return n-gram frequencies. The return value is a dict
    mapping the length of the n-gram to a collections.Counter
    object of n-gram tuple and number of times that n-gram occurred.
    Returned dict includes n-grams of length min_length to max_length.
    """
    lengths = range(min_length, max_length + 1)
    ngrams = {length: collections.Counter() for length in lengths}
    queue = collections.deque(maxlen=max_length)

    # Helper function to add n-grams at start of current queue to dict
    def add_queue():
        current = tuple(queue)
        for length in lengths:
            if len(current) >= length:
                ngrams[length][current[:length]] += 1

    # Loop through all lines and words and add n-grams to dict
    for line in lines:
        for word in tokenize(line):
            queue.append(word)
            if len(queue) >= max_length:
                add_queue()

    # Make sure we get the n-grams at the tail end of the queue
    while len(queue) > min_length:
        queue.popleft()
        add_queue()

    return ngrams


def print_most_frequent(ngrams, num=10):
    """Print num most common n-grams of each length in n-grams dict."""
    for n in sorted(ngrams):
        print('----- {} most common {}-grams -----'.format(num, n))
        for gram, count in ngrams[n].most_common(num):
            print('{0}: {1}'.format(' '.join(gram), count))
        print('')

# %%
ngrams = count_ngrams(df['Job_Responsibility'].astype(str).values)

# %%
print_most_frequent(ngrams,1000)
# Out:
# ----- 1000 most common 2-grams -----
# of the: 8795
# must have: 5795
# knowledge of: 5506
# experience in: 5396
# design and: 4714
# with the: 4429
# understanding of: 4429
# and maintain: 4295
# ability to: 4283
# to the: 4273
# in the: 3989
# experience with: 3826
# for the: 3737
# to ensure: 3689
# to work: 3656
# knowledge in: 3646
# and other: 3635
# will be: 3588
# knowledge on: 3376
# such as: 3283
# work with: 3274
# responsible for: 3234
# able to: 3178
# as per: 2678
# and implement: 2620
# social media: 2514
# software development: 2488
# develop and: 2450
# good knowledge: 2384
# must be: 2370
# should have: 2258
# team members: 2231
# by the: 2155
# on the: 2131
# in a: 2124
# development and: 2121
# based on: 2087
# and develop: 2054
# strong knowledge: 2015
# asp net: 1987
# the company: 1956
# best practices: 1869
# and software: 1857
# and maintenance: 1855
# collaborate with: 1848
# front end: 1843
# of all: 1828
# experience on: 1808
# a team: 1797
# web application: 1779
# any other: 1763
# software and: 1745
# requirements and: 1744
# as a: 1730
# support to: 1712
# systems and: 1696
# team to: 1689
# the team: 1680
# working with: 1649
# maintenance of: 1649
# be able: 1638
# according to: 1636
# and ensure: 1635
# object oriented: 1632
# to develop: 1615
# is a: 1577
# new technologies: 1567
# ensure the: 1553
# have experience: 1549
# should be: 1526
# sql server: 1526
# assigned by: 1500
# the project: 1485
# as well: 1485
# web applications: 1462
# work on: 1447
# and support: 1431
# hardware and: 1425
# participate in: 1424
# and design: 1420
# and manage: 1414
# and provide: 1406
# have to: 1403
# the development: 1380
# well as: 1376
# application development: 1362
# have good: 1343
# to meet: 1339
# closely with: 1328
# you will: 1324
# hardware software: 1318
# the management: 1294
# back end: 1258
# implementation of: 1252
# digital marketing: 1245
# problem solving: 1243
# ensure that: 1217
# maintain and: 1215
# of software: 1195
# up to: 1176
# technical support: 1175
# to be: 1175
# good understanding: 1166
# development of: 1164
# with other: 1162
# and network: 1154
# life cycle: 1153
# the organization: 1146
# support and: 1138
# and troubleshooting: 1137
# plan and: 1133
# and or: 1130
# need to: 1127
# work in: 1122
# html css: 1122
# company s: 1117
# applications and: 1112
# development team: 1107
# sound knowledge: 1106
# web based: 1100
# follow up: 1097
# hands on: 1096
# web services: 1091
# working experience: 1081
# and execute: 1077
# business requirements: 1076
# high quality: 1076
# and development: 1072
# within the: 1071
# looking for: 1070
# javascript jquery: 1069
# in php: 1066
# as required: 1061
# to date: 1056
# for all: 1055
# and work: 1050
# e commerce: 1050
# and implementation: 1049
# and maintaining: 1039
# analysis and: 1036
# e g: 1036
# with a: 1035
# teams to: 1032
# standards and: 1024
# team and: 1017
# a plus: 1009
# of web: 1009
# research and: 1008
# we are: 1008
# familiarity with: 1005
# technologies and: 1005
# work closely: 999
# tools and: 994
# and data: 992
# design develop: 985
# system and: 983
# support for: 979
# of a: 976
# to create: 974
# to improve: 971
# new features: 971
# in order: 968
# the business: 965
# order to: 964
# testing and: 961
# and the: 960
# monitoring and: 959
# and technical: 954
# the product: 953
# management and: 950
# configure and: 938
# have knowledge: 938
# of it: 934
# html5 css3: 932
# be a: 925
# day to: 924
# be responsible: 924
# to day: 920
# assist in: 918
# related to: 907
# test and: 904
# third party: 903
# to provide: 903
# communicate with: 902
# create and: 898
# security and: 894
# to understand: 888
# installation and: 887
# maintenance and: 885
# knowledge and: 884
# performance and: 874
# coordinate with: 873
# problems and: 868
# experience of: 866
# communication skills: 861
# and web: 858
# planning and: 857
# all the: 848
# manage and: 842
# to end: 841
# and performance: 838
# the software: 836
# understand the: 828
# provide technical: 827
# designing and: 823
# computer hardware: 820
# to identify: 815
# with team: 813
# issues and: 798
# test cases: 798
# to support: 797
# products and: 789
# on a: 789
# end user: 784
# end users: 779
# are looking: 778
# and services: 774
# development experience: 773
# design patterns: 772
# to achieve: 772
# and report: 771
# and test: 771
# of data: 768
# identify and: 767
# of new: 765
# when required: 760
# and resolve: 760
# and procedures: 755
# have a: 752
# familiar with: 742
# monitor and: 736
# to maintain: 730
# services and: 727
# on experience: 727
# knowledge about: 723
# operating systems: 722
# to deliver: 719
# process and: 713
# quality and: 713
# performance of: 712
# and security: 708
# at least: 706
# and system: 706
# have strong: 703
# and troubleshoot: 702
# client s: 701
# lan wan: 700
# cross functional: 696
# for new: 694
# contribute to: 694
# part of: 690
# from the: 689
# as assigned: 687
# trouble shooting: 682
# network and: 681
# it related: 678
# access control: 676
# configuration and: 676
# net mvc: 675
# to build: 674
# to design: 672
# under pressure: 671
# software design: 665
# implement and: 665
# work under: 661
# ms sql: 661
# prepare and: 660
# specifications and: 658
# as needed: 658
# maintain the: 655
# build and: 655
# with clients: 654
# design development: 652
# in english: 650
# solutions to: 650
# trends and: 647
# working knowledge: 642
# project management: 642
# search engine: 641
# skills and: 640
# of android: 640
# work as: 640
# development life: 639
# oriented programming: 636
# for a: 636
# and best: 633
# data and: 632
# required to: 632
# and when: 631
# it support: 631
# and developing: 630
# time to: 629
# to have: 629
# the client: 627
# implement new: 627
# with all: 623
# and implementing: 616
# and build: 615
# user experience: 615
# with different: 615
# as and: 613
# in depth: 612
# code and: 611
# install and: 610
# working on: 609
# years of: 608
# and managing: 605
# and update: 604
# the technical: 602
# design build: 602
# skills in: 601
# manage the: 601
# and monitor: 600
# to learn: 599
# and external: 599
# if you: 597
# needs and: 597
# the latest: 597
# provide support: 596
# policies and: 595
# applications for: 593
# sql queries: 593
# to manage: 592
# of network: 591
# solid understanding: 591
# server and: 591
# on time: 590
# the following: 590
# and management: 588
# php mysql: 587
# communication with: 586
# members and: 586
# use of: 580
# quality assurance: 579
# nan nan: 578
# very good: 577
# support of: 577
# support the: 574
# other it: 571
# with internal: 568
# documentation and: 562
# a must: 562
# solutions and: 561
# and business: 560
# in developing: 559
# and testing: 559
# plans and: 559
# user interface: 558
# how to: 558
# the network: 556
# the it: 555
# a good: 555
# meet the: 554
# database design: 554
# and related: 554
# and user: 553
# and project: 553
# and to: 551
# and applications: 550
# and experience: 549
# set up: 549
# and quality: 548
# efficient code: 547
# expert in: 546
# content for: 546
# to define: 545
# technologies to: 544
# active directory: 543
# mobile applications: 542
# web development: 542
# practices and: 542
# develop new: 540
# processes and: 539
# all it: 538
# ui ux: 538
# of our: 538
# troubleshooting and: 537
# version control: 537
# types of: 536
# report to: 536
# the requirements: 535
# and database: 535
# evaluate and: 535
# variety of: 534
# internal and: 533
# procedures and: 533
# to make: 532
# other duties: 530
# troubleshoot and: 530
# the ability: 529
# management of: 528
# and follow: 527
# candidate must: 526
# to prepare: 525
# the system: 525
# and monitoring: 524
# to all: 522
# standard coding: 521
# to time: 518
# and hardware: 517
# have the: 516
# experienced in: 516
# in all: 515
# high performance: 514
# relationship with: 513
# development process: 513
# aspects of: 510
# technical and: 509
# up and: 509
# expertise in: 509
# i e: 508
# the website: 508
# and coordinate: 507
# multiple projects: 507
# operating system: 506
# computer systems: 506
# along with: 505
# team player: 503
# users and: 501
# web and: 500
# a strong: 498
# experience working: 495
# test plans: 495
# and improve: 495
# mobile apps: 494
# applications using: 493
# developing and: 491
# and analyze: 489
# and systems: 489
# you are: 488
# and configuration: 488
# new technology: 488
# jquery ajax: 486
# and all: 485
# adobe photoshop: 485
# responsible to: 484
# the design: 484
# installation configuration: 483
# open source: 481
# projects and: 480
# based applications: 480
# and reporting: 479
# server side: 476
# strong understanding: 475
# troubleshooting of: 475
# management system: 475
# high level: 473
# team of: 473
# and application: 473
# solutions by: 472
# and fix: 472
# and document: 472
# in software: 472
# to maximize: 472
# and processes: 472
# with cross: 471
# training to: 471
# technical documentation: 471
# date with: 469
# up with: 468
# implementation and: 467
# depth knowledge: 467
# development using: 467
# new and: 466
# information and: 466
# report and: 465
# to solve: 465
# and create: 464
# integration of: 464
# marketing campaigns: 463
# clients and: 462
# e mail: 461
# level of: 461
# analyze and: 460
# and configuring: 458
# application software: 458
# and configure: 458
# reports and: 458
# to implement: 456
# marketing and: 455
# and efficient: 455
# project manager: 455
# backup and: 454
# and make: 454
# clear understanding: 453
# installing and: 453
# relationships with: 453
# quality of: 453
# the entire: 452
# end to: 451
# in house: 451
# with new: 451
# management to: 451
# desktop laptop: 450
# requirement analysis: 450
# analyze the: 450
# architecture and: 449
# crystal report: 448
# complex sql: 448
# software to: 447
# you have: 446
# entity framework: 445
# basic knowledge: 445
# is required: 445
# unit testing: 444
# network security: 443
# disaster recovery: 442
# bug fixing: 442
# node js: 441
# capable to: 440
# to handle: 439
# throughout the: 439
# to resolve: 438
# the customer: 437
# web api: 436
# and mobile: 436
# setup and: 436
# media and: 435
# will have: 435
# and documentation: 434
# working in: 434
# it equipment: 434
# per the: 432
# a variety: 432
# to take: 431
# them into: 430
# in web: 430
# in an: 429
# in accordance: 429
# to use: 428
# and internet: 428
# and understand: 428
# angular js: 427
# and identify: 427
# mail server: 426
# the best: 426
# design principles: 426
# and evaluate: 425
# duties as: 423
# operation of: 422
# to write: 421
# in object: 420
# writing complex: 420
# and social: 420
# ideas and: 418
# regular basis: 417
# candidate will: 417
# capability of: 417
# or other: 416
# product development: 416
# develop test: 414
# follow the: 414
# and product: 414
# customers and: 414
# at the: 412
# capable of: 412
# equipment and: 411
# and service: 411
# self motivated: 411
# training and: 411
# functional teams: 411
# application using: 410
# photoshop illustrator: 410
# work independently: 408
# to software: 408
# application performance: 408
# applications to: 408
# large scale: 407
# of computer: 406
# develop software: 406
# willing to: 405
# for any: 404
# other team: 404
# it infrastructure: 403
# to determine: 403
# by using: 403
# the candidate: 401
# with customers: 401
# solutions for: 400
# accordance with: 400
# developers to: 400
# web technologies: 398
# tools such: 397
# cross browser: 395
# and customer: 395
# a timely: 395
# of applications: 395
# technical issues: 394
# apis and: 394
# design specifications: 394
# the implementation: 393
# execution of: 392
# and prepare: 392
# the performance: 392
# develop web: 392
# and technologies: 391
# windows server: 391
# etc to: 391
# to our: 390
# network problems: 390
# to increase: 390
# across the: 389
# internal teams: 389
# mobile application: 389
# business and: 388
# link building: 388
# operation and: 387
# user support: 387
# of business: 387
# to project: 387
# that are: 386
# business process: 386
# proficient in: 386
# the application: 386
# the quality: 386
# queries and: 385
# css javascript: 385
# and communicate: 385
# ip camera: 384
# of existing: 384
# related issues: 382
# sales and: 382
# react js: 382
# patterns and: 382
# web design: 382
# software systems: 380
# ownership of: 380
# and new: 380
# of writing: 380
# by management: 380
# performance tuning: 379
# ensure all: 376
# html5 css: 376
# and take: 375
# programming languages: 375
# provide it: 374
# the existing: 373
# do not: 373
# solving and: 373
# for our: 372
# lan and: 371
# act as: 371
# that the: 371
# developers and: 371
# to help: 370
# to perform: 370
# and integration: 370
# good communication: 369
# website and: 369
# designs and: 369
# to communicate: 368
# and optimize: 368
# sales target: 367
# javascript ajax: 367
# database and: 367
# well designed: 367
# bugs and: 365
# code for: 365
# participating in: 364
# email marketing: 364
# java script: 363
# vue js: 363
# to analyze: 362
# features and: 362
# and analysis: 362
# review and: 362
# install configure: 361
# installation of: 361
# of different: 361
# limited to: 361
# and databases: 361
# and it: 360
# of working: 360
# data sources: 359
# end development: 359
# kind of: 359
# ensure smooth: 358
# technology and: 358
# in different: 358
# delivery of: 358
# and its: 358
# documentation of: 358
# customer service: 358
# erp software: 357
# and javascript: 357
# and a: 357
# understanding and: 356
# candidate should: 356
# team member: 356
# the web: 355
# design pattern: 354
# end and: 354
# carry out: 354
# in java: 354
# ui design: 353
# of projects: 353
# 3 years: 353
# and also: 352
# setting up: 352
# establish and: 352
# and debugging: 350
# document and: 350
# excellent capability: 350
# make sure: 350
# net c: 349
# other task: 349
# this position: 348
# and ensuring: 348
# development efficiency: 348
# rest api: 347
# product and: 347
# and deliver: 346
# solving skills: 346
# 2 years: 346
# data from: 346
# capability to: 346
# project requirements: 345
# requirements to: 345
# servers and: 344
# all aspects: 344
# with business: 344
# on web: 344
# to customer: 344
# monitor the: 344
# and ship: 344
# based application: 343
# erp system: 343
# wordpress theme: 343
# develop a: 342
# api integration: 342
# css3 javascript: 341
# c asp: 341
# requirement and: 341
# not limited: 341
# type of: 340
# php and: 340
# communication and: 340
# jquery and: 340
# business needs: 340
# across multiple: 339
# it systems: 339
# team for: 339
# the user: 339
# ship new: 339
# define design: 339
# lead the: 338
# the database: 338
# for both: 337
# and their: 337
# and in: 337
# members to: 337
# unit test: 337
# with vendors: 337
# services to: 336
# analysis of: 336
# deadlines and: 336
# analyze design: 336
# organization s: 336
# but not: 336
# web service: 335
# and requirements: 335
# software solutions: 335
# with technical: 335
# security of: 333
# to management: 333
# requirements for: 333
# user requirements: 333
# data backup: 332
# of object: 332
# fix bugs: 332
# and solving: 331
# android and: 331
# that all: 331
# with our: 331
# a project: 331
# work experience: 331
# liaise with: 330
# timely manner: 330
# as necessary: 330
# long term: 329
# websites and: 329
# head office: 328
# of hardware: 328
# improve the: 328
# as the: 328
# learn new: 327
# graphic design: 327
# by studying: 327
# end technologies: 327
# relational database: 327
# and improving: 327
# code design: 327
# of user: 326
# data center: 325
# with web: 325
# assist to: 325
# in line: 325
# timely and: 325
# online marketing: 324
# for future: 324
# mobile app: 324
# be an: 323
# information technology: 323
# and problem: 323
# and perform: 323
# and written: 322
# and translate: 322
# configuration of: 322
# the data: 322
# infrastructure and: 322
# laravel framework: 321
# of various: 321
# and architecture: 320
# on site: 320
# line with: 320
# changes to: 319
# by developing: 318
# printers and: 318
# in any: 318
# decision making: 318
# google analytics: 317
# with development: 317
# of code: 317
# the sales: 316
# control and: 316
# development projects: 316
# technical requirements: 315
# and standards: 315
# to clients: 314
# excellent knowledge: 314
# php laravel: 314
# and recommend: 314
# involved in: 314
# team in: 314
# write clean: 314
# reusable code: 313
# all digital: 313
# configuring computer: 313
# with various: 313
# of work: 312
# technical team: 312
# maximize development: 312
# maintain a: 312
# operations and: 311
# and marketing: 311
# can be: 311
# to apply: 311
# have sound: 311
# on php: 311
# client and: 310
# are met: 310
# keyword research: 310
# with client: 310
# added advantage: 309
# for web: 308
# and lead: 308
# other tasks: 308
# and knowledge: 307
# to do: 307
# network performance: 307
# teams and: 307
# and server: 306
# project team: 306
# and training: 306
# data entry: 306
# phases of: 305
# etc and: 305
# continuously discover: 305
# when necessary: 305
# on multiple: 304
# and working: 304
# a high: 304
# of any: 303
# javascript and: 303
# server 2008: 302
# discover evaluate: 302
# range of: 302
# tools like: 302
# reports to: 301
# write and: 301
# responsive design: 301
# business processes: 301
# collaborating with: 300
# organization and: 300
# responsive web: 300
# of php: 299
# skill in: 299
# r d: 299
# project and: 298
# maintain all: 298
# documents and: 298
# application and: 298
# time and: 297
# ajax jquery: 297
# is must: 297
# execute all: 297
# the overall: 297
# of information: 297
# network hardware: 296
# restful apis: 296
# web server: 296
# on page: 296
# css and: 295
# full stack: 295
# android platform: 295
# sql and: 295
# deep knowledge: 295
# with existing: 294
# and deploy: 294
# and existing: 294
# extensive knowledge: 294
# and well: 294
# of experience: 294
# design for: 294
# browser compatibility: 293
# has to: 293
# for different: 293
# a regular: 292
# respond to: 292
# analyzing and: 292
# development in: 292
# for business: 292
# client requirements: 292
# testable and: 292
# and tools: 292
# assist with: 292
# wi fi: 292
# activities and: 291
# quality code: 291
# and deployment: 291
# on all: 290
# in design: 290
# and operational: 290
# daily weekly: 290
# stakeholders and: 290
# in wordpress: 290
# diagnosing and: 289
# with project: 289
# industry trends: 289
# and communication: 289
# file server: 289
# coordination with: 288
# anti virus: 288
# to team: 288
# the use: 288
# task assigned: 288
# using the: 288
# availability and: 288
# per requirement: 288
# testing of: 287
# knowledge transfer: 287
# switch router: 287
# tasks assigned: 287
# compliance with: 287
# and others: 287
# using php: 286
# or software: 286
# of design: 286
# team leader: 286
# to complete: 286
# party apis: 286
# systems to: 286
# of database: 286
# restful api: 285
# existing systems: 285
# communication skill: 285
# on software: 285
# will work: 285
# and help: 285
# coding convention: 285
# in c: 284
# designed testable: 284
# write well: 284
# php framework: 284
# of project: 284
# data protection: 284
# objective c: 283
# into the: 283
# users to: 283
# programming and: 283
# code review: 283
# to produce: 283
# in javascript: 282
# support in: 282
# in microsoft: 282
# customer satisfaction: 282
# years experience: 281
# experience and: 281
# monitoring of: 281
# focus on: 281
# and networks: 281
# for various: 280
# devices and: 280
# pl sql: 280
# app development: 280
# root cause: 280
# stored procedures: 279
# to enhance: 279
# adobe illustrator: 279
# fixing and: 278

# %%
skills = pd.read_csv(os.path.join(DATA,'skills.csv'))

# %%
skills = skills.fillna(0)
skills.index = skills.Skills
skills['Skills'].tolist()
# Out:
# ['PHP',
#  'Database',
#  'SQL',
#  'JavaScript',
#  'SEO',
#  'Android',
#  'CSS',
#  'Oracle',
#  'HTML',
#  'MySQL',
#  ' C ',
#  'JAVA',
#  'WordPress',
#  'Laravel',
#  'Linux',
#  'jQuery',
#  'iOS',
#  'Bootstrap',
#  'AJAX',
#  'OOP',
#  'ASP.NET',
#  'Angular',
#  'SQL Server',
#  'QA',
#  'Excel',
#  'PowerPoint',
#  'Word',
#  'OneNote',
#  'Photoshop',
#  'Illustrator']

# %%
for year in years:
    skills[str(year)] = 0
    skills[str(year)] = skills[str(year)].astype(int)

# %%
for year in tqdm(years):
    temp_df = df[df['Year'] == year]
    for context in temp_df['Job_Responsibility'].values:
        for skill in skills['Skills'].tolist():
            if str(skill).lower() in str(context).lower():
                skills.loc[skill,str(year)] += 1
# Out:
# 100%|██████████| 6/6 [00:11<00:00,  1.96s/it]

# %%
skills.drop(['Skills'],axis=1,inplace=True)

# %%
yr_len = []
for year in years:
    temp_df = df[df['Year'] == year]
    yr_len.append(len(temp_df))
yr_len
# Out:
# [5039, 5275, 5323, 5570, 4245, 2865]

# %%
plt.rcParams['figure.figsize']= (12,12)
wc = WordCloud(background_color="white",width=1000,height=1000, max_words=50,relative_scaling=0.1,normalize_plurals=False).generate_from_frequencies(skills.sum(axis=1))
plt.imshow(wc)
plt.savefig('SkillWordCloud.png',dpi=350)

# %%
percentage_df = skills/yr_len

# %%
years = list(range(2016,2022))
skill_rank_df = pd.DataFrame(columns =[*years])
for YEAR in years:
    year_df = skills.loc[:,str(YEAR)]
    top_title = year_df.sort_values(ascending=False).index.tolist()
    print(top_title)
    for rank,title in enumerate(top_title):
        skill_rank_df.loc[title,YEAR] = rank+1
# Out:
# ['SQL', 'Database', 'JAVA', 'HTML', 'CSS', 'PHP', 'JavaScript', 'jQuery', 'Excel', 'MySQL', 'Word', 'AJAX', 'Bootstrap', 'Oracle', 'SQL Server', 'OOP', 'Linux', 'ASP.NET', 'WordPress', 'Android', 'iOS', 'Angular', 'Photoshop', 'Laravel', 'Illustrator', 'SEO', 'QA', 'PowerPoint', ' C ', 'Power Point', 'Photo Shop', 'One Note']
# ['SQL', 'JAVA', 'Database', 'PHP', 'HTML', 'CSS', 'JavaScript', 'jQuery', 'Excel', 'MySQL', 'Word', 'AJAX', 'Bootstrap', 'Linux', 'Android', 'Angular', 'OOP', 'Oracle', 'SQL Server', 'ASP.NET', 'iOS', 'WordPress', 'Laravel', 'Photoshop', 'SEO', 'Illustrator', 'QA', 'PowerPoint', 'Power Point', ' C ', 'Photo Shop', 'One Note']
# ['Database', 'JAVA', 'SQL', 'HTML', 'CSS', 'PHP', 'JavaScript', 'Excel', 'Word', 'jQuery', 'MySQL', 'AJAX', 'Android', 'Angular', 'Laravel', 'Bootstrap', 'SQL Server', 'Linux', 'ASP.NET', 'WordPress', 'Photoshop', 'SEO', 'Oracle', 'OOP', 'iOS', 'Illustrator', 'QA', 'PowerPoint', 'Power Point', ' C ', 'Photo Shop', 'One Note']
# ['Database', 'SQL', 'JAVA', 'JavaScript', 'HTML', 'CSS', 'PHP', 'Excel', 'jQuery', 'MySQL', 'Word', 'Angular', 'Laravel', 'AJAX', 'Bootstrap', 'Android', 'OOP', 'Oracle', 'Linux', 'SEO', 'ASP.NET', 'iOS', 'Photoshop', 'SQL Server', 'WordPress', 'Illustrator', 'QA', 'PowerPoint', 'Power Point', ' C ', 'Photo Shop', 'One Note']
# ['Database', 'JAVA', 'SQL', 'HTML', 'JavaScript', 'CSS', 'PHP', 'Word', 'MySQL', 'jQuery', 'Excel', 'Laravel', 'OOP', 'Bootstrap', 'Angular', 'SEO', 'AJAX', 'WordPress', 'Android', 'Linux', 'iOS', 'SQL Server', 'Oracle', 'ASP.NET', 'Photoshop', 'QA', 'Illustrator', 'PowerPoint', 'Power Point', ' C ', 'One Note', 'Photo Shop']
# ['Database', 'JAVA', 'SQL', 'JavaScript', 'HTML', 'CSS', 'PHP', 'Word', 'Excel', 'MySQL', 'jQuery', 'Android', 'SEO', 'Laravel', 'Angular', 'WordPress', 'iOS', 'Bootstrap', 'AJAX', 'OOP', 'Linux', 'Oracle', 'SQL Server', 'ASP.NET', 'QA', 'Photoshop', 'Illustrator', 'PowerPoint', ' C ', 'Power Point', 'Photo Shop', 'One Note']

# %%
skill_rank_df.head(10)
# Out:
#            2016 2017 2018 2019 2020 2021
# SQL           1    1    3    2    3    3
# Database      2    3    1    1    1    1
# JAVA          3    2    2    3    2    2
# HTML          4    5    4    5    4    5
# CSS           5    6    5    6    6    6
# PHP           6    4    6    7    7    7
# JavaScript    7    7    7    4    5    4
# jQuery        8    8   10    9   10   11
# Excel         9    9    8    8   11    9
# MySQL        10   10   11   10    9   10

# %%
skill_final_df = pd.DataFrame(index=skill_rank_df.index, columns = pd.MultiIndex.from_product([years,['Rank','Percentage']]))

# %%
for col in skill_rank_df.columns:
    skill_final_df[col,'Rank'] = skill_rank_df[col]
    skill_final_df[col,'Percentage'] = percentage_df[str(col)]    
# for col in percentage_df.columns:

# %%
skill_final_df.to_csv('data/Skill_Rank.csv',float_format='%.2f')

# %%
percentage_df.columns
# Out:
# Index(['2016', '2017', '2018', '2019', '2020', '2021'], dtype='object')

# %%
skill_corr_df = pd.DataFrame(index = df.index,columns=skills['Skills'].tolist()).fillna(0)

# %%
for i , context in enumerate((df['Job_Responsibility'] + df['Job_Context']).values):
    for skill in skills['Skills'].tolist():
        if str(skill).lower() in str(context).lower():
            skill_corr_df.loc[i,skill] += 1

# %%
corr_df = skill_corr_df.corr()

# %%
mask = np.zeros_like(corr_df,dtype=np.bool)
mask[np.triu_indices_from(mask)] = True

plt.rcParams['figure.figsize'] = (16,16)
ax = sns.heatmap(corr_df,mask=mask,cmap='Reds')
cbar = ax.collections[0].colorbar
# cbar.ax.tick_params(labelsize=20)
# plt.xticks(fontsize=20)
# plt.yticks(fontsize=20)
plt.savefig('SKill_heatmap.png',dpi=350)
# Out:
# <ipython-input-26-27dc961c0057>:1: DeprecationWarning: `np.bool` is a deprecated alias for the builtin `bool`. To silence this warning, use `bool` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.bool_` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   mask = np.zeros_like(corr_df,dtype=np.bool)

# %%
skill_corr_df['Title']  = df['ONET Title']

# %%
job_skill_corr = skill_corr_df.join(pd.get_dummies(skill_corr_df['Title']))

# %%
corr_df = job_skill_corr.corr()

# %%
# mask = np.zeros_like(corr_df,dtype=np.bool)
# mask[np.triu_indices_from(mask)] = True

plt.rcParams['figure.figsize'] = (24,16)
ax = sns.heatmap(corr_df,cmap='Reds')
cbar = ax.collections[0].colorbar
# cbar.ax.tick_params(labelsize=20)
# plt.xticks(fontsize=20)
# plt.yticks(fontsize=20)
plt.tight_layout()
plt.savefig('Skill_Title_Corr.png',dpi=350)

# %%
len(skill_corr_df['Title'].value_counts())
# Out:
# 26

# %%
corr_df.drop(skills['Skills'].values,inplace=True)

# %%
corr_df.drop(skill_corr_df['Title'].values,axis=1,inplace=True)
