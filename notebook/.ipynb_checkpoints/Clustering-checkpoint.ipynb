# %%
import pandas as pd 
import numpy as np
import seaborn as sns
import os
import matplotlib.pyplot as plt
import spacy
from tqdm import tqdm
from sklearn.decomposition import PCA
from sklearn.manifold import TSNE
from sklearn.preprocessing import LabelEncoder
import colorcet
plt.style.use('fivethirtyeight')
plt.rcParams['figure.figsize'] = (12,12)

# %%
GRAPH = 'Results/Graphs'
TABLE = 'Results/Tables'
DATA = '../data/'

# %%
df = pd.read_csv(os.path.join(DATA,'Dataset_v4.csv'))

# %%
df['TitleCode'] = LabelEncoder().fit_transform(df['ONET Title'])

# %%
nlp = spacy.load("en_core_web_lg")

# %%
vector_list = []
for context in tqdm((df['Job_Context'] + df['Job_Responsibility']).values):
    vector = nlp(str(context)).vector
    vector_list.append(vector)
# Out:
# 100%|██████████| 28316/28316 [05:12<00:00, 90.64it/s]

# %%
with open('../data/vector.npy','rb') as f:
    vector_list = np.load(f)

# %%
vector_list.shape
# Out:
# (28316, 768)

# %%
pca = PCA(n_components=2)
pca.fit(vector_list)
reduced = pca.transform(vector_list)

# %%
tsne = TSNE(3)
reduced = tsne.fit_transform(vector_list)
# Out:
# ---------------------------------------
# KeyboardInterruptTraceback (most recent call last)
# <ipython-input-53-39ab63941783> in <module>
#       1 tsne = TSNE(3)
# ----> 2 reduced = tsne.fit_transform(vector_list)
#
# ~/.conda/envs/Srj/lib/python3.8/site-packages/sklearn/manifold/_t_sne.py in fit_transform(self, X, y)
#     930             Embedding of the training data in low-dimensional space.
#     931         """
# --> 932         embedding = self._fit(X)
#     933         self.embedding_ = embedding
#     934         return self.embedding_
#
# ~/.conda/envs/Srj/lib/python3.8/site-packages/sklearn/manifold/_t_sne.py in _fit(self, X, skip_num_points)
#     839         degrees_of_freedom = max(self.n_components - 1, 1)
#     840
# --> 841         return self._tsne(P, degrees_of_freedom, n_samples,
#     842                           X_embedded=X_embedded,
#     843                           neighbors=neighbors_nn,
#
# ~/.conda/envs/Srj/lib/python3.8/site-packages/sklearn/manifold/_t_sne.py in _tsne(self, P, degrees_of_freedom, n_samples, X_embedded, neighbors, skip_num_points)
#     895             opt_args['momentum'] = 0.8
#     896             opt_args['n_iter_without_progress'] = self.n_iter_without_progress
# --> 897             params, kl_divergence, it = _gradient_descent(obj_func, params,
#     898                                                           **opt_args)
#     899
#
# ~/.conda/envs/Srj/lib/python3.8/site-packages/sklearn/manifold/_t_sne.py in _gradient_descent(objective, p0, it, n_iter, n_iter_check, n_iter_without_progress, momentum, learning_rate, min_gain, min_grad_norm, verbose, args, kwargs)
#     361         kwargs['compute_error'] = check_convergence or i == n_iter - 1
#     362
# --> 363         error, grad = objective(p, *args, **kwargs)
#     364         grad_norm = linalg.norm(grad)
#     365
#
# ~/.conda/envs/Srj/lib/python3.8/site-packages/sklearn/manifold/_t_sne.py in _kl_divergence_bh(params, P, degrees_of_freedom, n_samples, n_components, angle, skip_num_points, verbose, compute_error, num_threads)
#     256     X_embedded = params.reshape(n_samples, n_components)
#     257
# --> 258     val_P = P.data.astype(np.float32, copy=False)
#     259     neighbors = P.indices.astype(np.int64, copy=False)
#     260     indptr = P.indptr.astype(np.int64, copy=False)
#
# KeyboardInterrupt:

# %%
fig,ax = plt.subplots()
ax.scatter(reduced[:,0],reduced[:,1],c=kmean,cmap=colorcet.fire)

# %%
def kmean(data,n,seed=0):
    from sklearn.cluster import KMeans
    kmeans = KMeans(n_clusters=n, init='k-means++', max_iter=300, n_init=100, random_state=seed)
    pred_y = kmeans.fit_predict(data)
    return pred_y

# %%
def get_elbow(X,k):
    from sklearn.cluster import KMeans
    wcss = []
    for i in tqdm(range(1, k+1)):
        kmeans = KMeans(n_clusters=i, init='k-means++', max_iter=300, n_init=10, random_state=0)
        kmeans.fit(X)
        wcss.append(kmeans.inertia_)
    plt.plot(range(1, k+1), wcss)
    plt.title('Elbow Method')
    plt.xlabel('Number of clusters')
    plt.ylabel('WCSS')
    plt.show()

# %%
get_elbow(vector_list,50)
# Out:
# 100%|██████████| 50/50 [15:18<00:00, 18.37s/it]

# %%
df['Cluster'] = kmean(vector_list,5)

# %%
df.groupby(['Cluster'])['JobTitle'].value_counts().to_csv('Test.csv')
